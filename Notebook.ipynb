# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null 
# !wget -q https://downloads.apache.org/spark/spark-3.1.1/spark-3.1.1-bin-hadoop2.7.tgz
# !tar xf spark-3.1.1-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
# !ls /usr/lib/jvm/
# Out:
# default-java		   java-11-openjdk-amd64     java-8-openjdk-amd64
# java-1.11.0-openjdk-amd64  java-1.8.0-openjdk-amd64

# %%
import os
os.environ["JAVA_HOME"]="/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"]="/content/spark-3.1.1-bin-hadoop2.7"

# %%
import findspark
findspark.init()

from pyspark.sql import SparkSession
#spark=SparkSession.builder.master("local[*]").getOrCreate()

from pyspark import SparkContext
sc = SparkContext("local", "First App")

# %%
import sys,tempfile,urllib
from pyspark.sql.functions import *
from pyspark.sql import *

# %%
# !git clone "https://github.com/chetankumar1996/hr-analytics-using-spark.git"
# Out:
# fatal: destination path 'hr-analytics-using-spark' already exists and is not an empty directory.

# %%
# !ls hr-analytics-using-spark
# Out:
# aug_train.csv  README.md

# %%
sqlContext = SQLContext(sc)
train_df=sqlContext.read.option("header",True)\
                   .option("inferSchema",True)\
                   .csv("hr-analytics-using-spark/aug_train.csv")

# %%
train_df.show(30)
# Out:
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------------+--------------+------+
# |enrollee_id|    city|city_development_index|gender| relevent_experience|enrolled_university|education_level|major_discipline|experience|company_size|  company_type|last_new_job|training_hours|target|
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------------+--------------+------+
# |       8949|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|       >20|        null|          null|           1|            36|   1.0|
# |      29725| city_40|    0.7759999999999999|  Male|No relevent exper...|      no_enrollment|       Graduate|            STEM|        15|       50-99|       Pvt Ltd|          >4|            47|   0.0|
# |      11561| city_21|                 0.624|  null|No relevent exper...|   Full time course|       Graduate|            STEM|         5|        null|          null|       never|            83|   0.0|
# |      33241|city_115|                 0.789|  null|No relevent exper...|               null|       Graduate| Business Degree|        <1|        null|       Pvt Ltd|       never|            52|   1.0|
# |        666|city_162|                 0.767|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|       >20|       50-99|Funded Startup|           4|             8|   0.0|
# |      21651|city_176|                 0.764|  null|Has relevent expe...|   Part time course|       Graduate|            STEM|        11|        null|          null|           1|            24|   1.0|
# |      28806|city_160|                  0.92|  Male|Has relevent expe...|      no_enrollment|    High School|            null|         5|       50-99|Funded Startup|           1|            24|   0.0|
# |        402| city_46|                 0.762|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        13|         <10|       Pvt Ltd|          >4|            18|   1.0|
# |      27107|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|       50-99|       Pvt Ltd|           1|            46|   1.0|
# |        699|city_103|                  0.92|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        17|      10000+|       Pvt Ltd|          >4|           123|   0.0|
# |      29452| city_21|                 0.624|  null|No relevent exper...|   Full time course|    High School|            null|         2|        null|          null|       never|            32|   1.0|
# |      23853|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         5|   5000-9999|       Pvt Ltd|           1|           108|   0.0|
# |      25619| city_61|    0.9129999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|       >20|   1000-4999|       Pvt Ltd|           3|            23|   0.0|
# |       5826| city_21|                 0.624|  Male|No relevent exper...|               null|           null|            null|         2|        null|          null|       never|            24|   0.0|
# |       8722| city_21|                 0.624|  null|No relevent exper...|   Full time course|    High School|            null|         5|        null|          null|       never|            26|   0.0|
# |       6588|city_114|    0.9259999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        16|       10/49|       Pvt Ltd|          >4|            18|   0.0|
# |       4167|city_103|                  0.92|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         1|       50-99|       Pvt Ltd|       never|           106|   0.0|
# |       5764| city_21|                 0.624|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         2|   5000-9999|       Pvt Ltd|           2|             7|   0.0|
# |       2156| city_21|                 0.624|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|      10000+|       Pvt Ltd|       never|            23|   1.0|
# |      11399| city_13|    0.8270000000000001|Female|Has relevent expe...|      no_enrollment|       Graduate|            Arts|         4|        null|          null|           1|           132|   1.0|
# |      31972|city_159|                 0.843|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|        11|     100-500|       Pvt Ltd|           1|            68|   0.0|
# |      19061|city_114|    0.9259999999999999|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|        11|     100-500|       Pvt Ltd|           2|            50|   0.0|
# |       6491|city_102|                 0.804|  null|Has relevent expe...|      no_enrollment|        Masters|            STEM|        10|        null|          null|           1|            48|   0.0|
# |       7041| city_40|    0.7759999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|      Humanities|        <1|   1000-4999|       Pvt Ltd|           1|            65|   0.0|
# |      22767| city_21|                 0.624|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         5|   1000-4999|       Pvt Ltd|           1|            13|   0.0|
# |      14505| city_67|                 0.855|  null|No relevent exper...|      no_enrollment|    High School|            null|         4|        null|          null|       never|            22|   0.0|
# |      17139| city_21|                 0.624|  null|Has relevent expe...|   Part time course|       Graduate|            STEM|        14|     500-999|       Pvt Ltd|           1|           148|   1.0|
# |      28476|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            Arts|         5|        null|          null|           2|            72|   0.0|
# |      21538|city_100|                 0.887|  Male|Has relevent expe...|      no_enrollment|    High School|            null|        11|         <10|       Pvt Ltd|           1|             8|   1.0|
# |      10408| city_21|                 0.624|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        18|       50-99|Funded Startup|           2|            68|   1.0|
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------------+--------------+------+
# only showing top 30 rows

# %%
train_df.count()
# Out:
# 19158

# %%
train_df.printSchema()
# Out:
# root
#  |-- enrollee_id: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- city_development_index: double (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- relevent_experience: string (nullable = true)
#  |-- enrolled_university: string (nullable = true)
#  |-- education_level: string (nullable = true)
#  |-- major_discipline: string (nullable = true)
#  |-- experience: string (nullable = true)
#  |-- company_size: string (nullable = true)
#  |-- company_type: string (nullable = true)
#  |-- last_new_job: string (nullable = true)
#  |-- training_hours: integer (nullable = true)
#  |-- target: double (nullable = true)

# %%
train_df.describe().show()
# Out:
# +-------+------------------+-------+----------------------+------+--------------------+-------------------+---------------+----------------+-----------------+------------+-------------------+------------------+-----------------+-------------------+
# |summary|       enrollee_id|   city|city_development_index|gender| relevent_experience|enrolled_university|education_level|major_discipline|       experience|company_size|       company_type|      last_new_job|   training_hours|             target|
# +-------+------------------+-------+----------------------+------+--------------------+-------------------+---------------+----------------+-----------------+------------+-------------------+------------------+-----------------+-------------------+
# |  count|             19158|  19158|                 19158| 14650|               19158|              18772|          18698|           16345|            19093|       13220|              13018|             18735|            19158|              19158|
# |   mean|16875.358179350664|   null|    0.8288480008351684|  null|                null|               null|           null|            null|8.101799149492967|        null|               null| 1.618409913030093|65.36689633573442|0.24934753105752167|
# | stddev| 9616.292592160924|   null|   0.12336175686054515|  null|                null|               null|           null|            null|4.934599764055633|        null|               null|0.9321202932740219|60.05846192467765|0.43264663445625307|
# |    min|                 1| city_1|   0.44799999999999995|Female|Has relevent expe...|   Full time course|       Graduate|            Arts|                1|       10/49|Early Stage Startup|                 1|                1|                0.0|
# |    max|             33380|city_99|    0.9490000000000001| Other|No relevent exper...|      no_enrollment| Primary School|            STEM|              >20|         <10|            Pvt Ltd|             never|              336|                1.0|
# +-------+------------------+-------+----------------------+------+--------------------+-------------------+---------------+----------------+-----------------+------------+-------------------+------------------+-----------------+-------------------+

# %% [markdown]
# Cleaning

# %% [markdown]
# "gender","relevent_experience","enrolled_university","education_level","last_new_job","company_type","company_size","experience","major_discipline"

# %%
 train_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in train_df.columns]).show()
# Out:
# +-----------+----+----------------------+------+-------------------+-------------------+---------------+----------------+----------+------------+------------+------------+--------------+------+
# |enrollee_id|city|city_development_index|gender|relevent_experience|enrolled_university|education_level|major_discipline|experience|company_size|company_type|last_new_job|training_hours|target|
# +-----------+----+----------------------+------+-------------------+-------------------+---------------+----------------+----------+------------+------------+------------+--------------+------+
# |          0|   0|                     0|  4508|                  0|                386|            460|            2813|        65|        5938|        6140|         423|             0|     0|
# +-----------+----+----------------------+------+-------------------+-------------------+---------------+----------------+----------+------------+------------+------------+--------------+------+

# %%
train_df.select("training_hours").distinct().show()
# Out:
# +--------------+
# |training_hours|
# +--------------+
# |           148|
# |            31|
# |            85|
# |            65|
# |            53|
# |           133|
# |           322|
# |            78|
# |           108|
# |           155|
# |            34|
# |           101|
# |           126|
# |            81|
# |            28|
# |           210|
# |           300|
# |            76|
# |            26|
# |            27|
# +--------------+
# only showing top 20 rows

# %%
train_df1=train_df.withColumn("experience",regexp_replace("experience", ">", ""))

# %%
train_df1=train_df1.withColumn("experience",regexp_replace("experience", "<", ""))

# %%
train_df1.select("experience").distinct().show()
# Out:
# +----------+
# |experience|
# +----------+
# |         7|
# |        15|
# |        11|
# |         3|
# |         8|
# |        16|
# |      null|
# |         5|
# |        18|
# |        17|
# |         6|
# |        19|
# |         9|
# |         1|
# |        20|
# |        10|
# |         4|
# |        12|
# |        13|
# |        14|
# +----------+
# only showing top 20 rows

# %%
train_df1.select("last_new_job").distinct().show()
# Out:
# +------------+
# |last_new_job|
# +------------+
# |           3|
# |        null|
# |       never|
# |           1|
# |           4|
# |          >4|
# |           2|
# +------------+

# %%
train_df1=train_df1.withColumn("last_new_job",regexp_replace("last_new_job", "never", "0"))
train_df1=train_df1.withColumn("last_new_job",regexp_replace("last_new_job", ">", ""))

# %%
train_df1.select("company_size").distinct().show()
# Out:
# +------------+
# |company_size|
# +------------+
# |        null|
# |       10/49|
# |     100-500|
# |       50-99|
# |         <10|
# |     500-999|
# |   5000-9999|
# |      10000+|
# |   1000-4999|
# +------------+

# %%
train_df1=train_df1.withColumn("company_size",regexp_replace("company_size", "<", "0-"))
train_df1=train_df1.withColumn("company_size",regexp_replace("company_size", "/", "-"))

# %%
train_df1.groupby("gender")\
        .count()\
        .show()
# Out:
# +------+-----+
# |gender|count|
# +------+-----+
# |  null| 4508|
# |Female| 1238|
# | Other|  191|
# |  Male|13221|
# +------+-----+

# %%
train_df1.groupby("major_discipline")\
        .count()\
        .show()
# Out:
# +----------------+-----+
# |major_discipline|count|
# +----------------+-----+
# | Business Degree|  327|
# |            null| 2813|
# |      Humanities|  669|
# |        No Major|  223|
# |           Other|  381|
# |            STEM|14492|
# |            Arts|  253|
# +----------------+-----+

# %%
train_df1.groupby("last_new_job")\
        .count()\
        .show()
# Out:
# +------------+-----+
# |last_new_job|count|
# +------------+-----+
# |           3| 1024|
# |           0| 2452|
# |        null|  423|
# |           1| 8040|
# |           4| 4319|
# |           2| 2900|
# +------------+-----+

# %%
train_df1.sort("city_development_index").show()
##.filter(train_df1.company_size.isNull() & train_df1.company_type.isNull()).show()
# Out:
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+-------------+------------+--------------+------+
# |enrollee_id|    city|city_development_index|gender| relevent_experience|enrolled_university|education_level|major_discipline|experience|company_size| company_type|last_new_job|training_hours|target|
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+-------------+------------+--------------+------+
# |      27970| city_33|   0.44799999999999995|  Male|No relevent exper...|      no_enrollment|       Graduate|            STEM|         1|        null|         null|           0|            73|   1.0|
# |      31179| city_33|   0.44799999999999995|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|       50-99|      Pvt Ltd|           1|            28|   0.0|
# |      18564| city_33|   0.44799999999999995|  null|No relevent exper...|   Full time course|       Graduate|            STEM|         4|        null|Public Sector|           4|            32|   1.0|
# |       8238| city_33|   0.44799999999999995|  null|Has relevent expe...|   Part time course|       Graduate|            STEM|        10|       50-99|          NGO|           4|            48|   1.0|
# |      26838| city_33|   0.44799999999999995|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         8|        null|         null|           4|            74|   0.0|
# |      30985| city_33|   0.44799999999999995|  null|No relevent exper...|   Full time course|       Graduate|            STEM|         2|        null|         null|           0|            43|   1.0|
# |      28317| city_33|   0.44799999999999995|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         8|       10-49|      Pvt Ltd|           2|            14|   0.0|
# |       3891| city_33|   0.44799999999999995|  Male|No relevent exper...|   Full time course|    High School|            null|         4|        null|         null|           0|            31|   0.0|
# |       4776| city_33|   0.44799999999999995|  null|No relevent exper...|   Full time course|        Masters|            STEM|         4|        null|      Pvt Ltd|           0|            66|   1.0|
# |      30131| city_33|   0.44799999999999995|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         4|     100-500|      Pvt Ltd|           1|            16|   0.0|
# |      10486| city_33|   0.44799999999999995|  null|No relevent exper...|   Full time course|       Graduate|           Other|         2|     500-999|Public Sector|           2|           154|   1.0|
# |      24256| city_33|   0.44799999999999995|  Male|No relevent exper...|      no_enrollment|       Graduate|            STEM|         4|       10-49|Public Sector|           1|            44|   1.0|
# |      16548| city_33|   0.44799999999999995|  null|No relevent exper...|   Full time course|       Graduate|            STEM|         1|   1000-4999|Public Sector|        null|            15|   1.0|
# |       4858| city_33|   0.44799999999999995|  null|No relevent exper...|   Part time course|        Masters|           Other|         2|        0-10|          NGO|           1|            23|   1.0|
# |      31194| city_33|   0.44799999999999995|  null|No relevent exper...|               null|    High School|            null|         5|        null|      Pvt Ltd|           0|            86|   1.0|
# |      19463| city_33|   0.44799999999999995|  Male|No relevent exper...|      no_enrollment|       Graduate|            STEM|         5|      10000+|      Pvt Ltd|           2|            36|   0.0|
# |        598| city_33|   0.44799999999999995|  null|Has relevent expe...|   Part time course|        Masters|            STEM|         6|        null|         null|           1|            18|   1.0|
# |      32068|city_126|                 0.479|  null|Has relevent expe...|      no_enrollment| Primary School|            null|        19|        null|      Pvt Ltd|           0|            62|   1.0|
# |      32562|city_126|                 0.479|  null|Has relevent expe...|      no_enrollment|           null|            null|        18|        null|         null|           0|            61|   1.0|
# |      29846|city_126|                 0.479|  null|No relevent exper...|               null| Primary School|            null|         2|        null|         null|           0|           167|   0.0|
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+-------------+------------+--------------+------+
# only showing top 20 rows

# %%
train_df1 = train_df1.withColumn("experience", train_df1["experience"].cast("integer"))
train_df1 = train_df1.withColumn("last_new_job", train_df1["last_new_job"].cast("integer"))

# %%
train_df1.stat.corr("city_development_index","experience")
# Out:
# 0.3336409683569583

# %%
from pyspark.sql.window import Window
window = Window.partitionBy('enrollee_id')\
               .orderBy('city_development_index')

filled_column = last(train_df1['company_type']).over(window)

train_df2 = train_df1.withColumn('company_type', filled_column)

# %%
train_df2.show()
# Out:
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------------+--------------+------+
# |enrollee_id|    city|city_development_index|gender| relevent_experience|enrolled_university|education_level|major_discipline|experience|company_size|  company_type|last_new_job|training_hours|target|
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------------+--------------+------+
# |        148| city_41|    0.8270000000000001|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        13|     100-500|       Pvt Ltd|           1|            52|   0.0|
# |        463| city_16|                  0.91|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        15|        null|          null|           2|             9|   0.0|
# |        496|city_160|                  0.92|  Male|Has relevent expe...|      no_enrollment|    High School|            null|        12|     100-500|       Pvt Ltd|           2|            74|   0.0|
# |        833| city_67|                 0.855|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|      10000+|       Pvt Ltd|           1|             2|   0.0|
# |       1238| city_28|    0.9390000000000001|  Male|Has relevent expe...|      no_enrollment|            Phd|            STEM|        14|       10-49|Funded Startup|           2|            13|   0.0|
# |       1342|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        10|      10000+| Public Sector|           4|           166|   0.0|
# |       1580| city_16|                  0.91|  Male|No relevent exper...|   Full time course|       Graduate|            STEM|         1|        null|          null|           0|             4|   0.0|
# |       1829| city_21|                 0.624|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         8|       10-49|       Pvt Ltd|           1|            98|   1.0|
# |       2142| city_76|                 0.698|  null|Has relevent expe...|      no_enrollment|    High School|            null|         5|        0-10|Funded Startup|           1|            44|   0.0|
# |       2866|city_114|    0.9259999999999999|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        18|       50-99|       Pvt Ltd|           3|            22|   0.0|
# |       3794|city_103|                  0.92|  Male|Has relevent expe...|   Full time course|       Graduate|            STEM|        20|        0-10|Funded Startup|           4|            50|   0.0|
# |       3918|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        20|        null|          null|           4|            99|   0.0|
# |       3997| city_16|                  0.91|  Male|No relevent exper...|      no_enrollment| Primary School|            null|         5|        null|       Pvt Ltd|           0|            11|   0.0|
# |       4101| city_67|                 0.855|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|        10|        null|          null|           1|            41|   0.0|
# |       4900|city_103|                  0.92|  Male|No relevent exper...|      no_enrollment|       Graduate|            STEM|        10|        null|          null|           4|           140|   1.0|
# |       4935|city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        20|        null|          null|           2|           144|   1.0|
# |       5518|city_165|                 0.903|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|     100-500|       Pvt Ltd|           1|            69|   0.0|
# |       6336|city_159|                 0.843|  Male|No relevent exper...|   Full time course|       Graduate|            STEM|         2|        null|          null|           0|            23|   0.0|
# |       6357|city_114|    0.9259999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        12|        null|          null|           0|            37|   0.0|
# |       6397|city_103|                  0.92|  null|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        20|       50-99|Funded Startup|           4|            43|   0.0|
# +-----------+--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------------+--------------+------+
# only showing top 20 rows

# %%
columns_to_drop = ['company_size','company_type','enrollee_id']
train_df2 = train_df1.drop(*columns_to_drop)

# %%
train_df2.printSchema()
# Out:
# root
#  |-- city: string (nullable = true)
#  |-- city_development_index: double (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- relevent_experience: string (nullable = true)
#  |-- enrolled_university: string (nullable = true)
#  |-- education_level: string (nullable = true)
#  |-- major_discipline: string (nullable = true)
#  |-- experience: integer (nullable = true)
#  |-- last_new_job: integer (nullable = true)
#  |-- training_hours: integer (nullable = true)
#  |-- target: double (nullable = true)

# %%
train_df2= train_df2.na.fill(value="Female",subset=["gender"])

# %%
train_df2=train_df2.na.drop(subset=["major_discipline"])

# %%
mode =train_df1.groupby("enrolled_university").count().orderBy("count", ascending=False).first()[0]
train_df2=train_df2.na.fill(value=mode,subset=["enrolled_university"])

# %%
df_stats = train_df1.select(
    avg(col('experience')).alias('mean'),
    avg(col('last_new_job')).alias('avg')
).collect()

# %%
mean = df_stats[0]['mean']

# %%
mean2=df_stats[0]['avg']

# %%
train_df2=train_df2.na.fill(value=mean,subset=["experience"])
train_df2=train_df2.na.fill(value=mean2,subset=["last_new_job"])

# %%
train_df2.show()
# Out:
# +--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------+
# |    city|city_development_index|gender| relevent_experience|enrolled_university|education_level|major_discipline|experience|last_new_job|training_hours|target|
# +--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------+
# |city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        20|           1|            36|   1.0|
# | city_40|    0.7759999999999999|  Male|No relevent exper...|      no_enrollment|       Graduate|            STEM|        15|           4|            47|   0.0|
# | city_21|                 0.624|Female|No relevent exper...|   Full time course|       Graduate|            STEM|         5|           0|            83|   0.0|
# |city_115|                 0.789|Female|No relevent exper...|      no_enrollment|       Graduate| Business Degree|         1|           0|            52|   1.0|
# |city_162|                 0.767|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|        20|           4|             8|   0.0|
# |city_176|                 0.764|Female|Has relevent expe...|   Part time course|       Graduate|            STEM|        11|           1|            24|   1.0|
# | city_46|                 0.762|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        13|           4|            18|   1.0|
# |city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|           1|            46|   1.0|
# |city_103|                  0.92|Female|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        17|           4|           123|   0.0|
# |city_103|                  0.92|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         5|           1|           108|   0.0|
# | city_61|    0.9129999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        20|           3|            23|   0.0|
# |city_114|    0.9259999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|            STEM|        16|           4|            18|   0.0|
# |city_103|                  0.92|Female|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         1|           0|           106|   0.0|
# | city_21|                 0.624|Female|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         2|           2|             7|   0.0|
# | city_21|                 0.624|Female|Has relevent expe...|      no_enrollment|       Graduate|            STEM|         7|           0|            23|   1.0|
# | city_13|    0.8270000000000001|Female|Has relevent expe...|      no_enrollment|       Graduate|            Arts|         4|           1|           132|   1.0|
# |city_159|                 0.843|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|        11|           1|            68|   0.0|
# |city_114|    0.9259999999999999|  Male|Has relevent expe...|      no_enrollment|        Masters|            STEM|        11|           2|            50|   0.0|
# |city_102|                 0.804|Female|Has relevent expe...|      no_enrollment|        Masters|            STEM|        10|           1|            48|   0.0|
# | city_40|    0.7759999999999999|  Male|Has relevent expe...|      no_enrollment|       Graduate|      Humanities|         1|           1|            65|   0.0|
# +--------+----------------------+------+--------------------+-------------------+---------------+----------------+----------+------------+--------------+------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import OneHotEncoder,StringIndexer,VectorAssembler

# %%
categoricalColumns = ["city","gender","relevent_experience","enrolled_university","education_level","major_discipline"]
stages = []

# %%
for categoricalCol in categoricalColumns:
    stringIndexer = StringIndexer(inputCol = categoricalCol, outputCol = categoricalCol + 'Index')
    encoder = OneHotEncoder(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "classVec"])
    stages += [stringIndexer, encoder]

# %%
label_stringIdx = StringIndexer(inputCol = 'target', outputCol = 'label')
stages += [label_stringIdx]

# %%
numericCols = ["experience","last_new_job","training_hours","city_development_index"]
assemblerInputs = [c + "classVec" for c in categoricalColumns] + numericCols
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]

# %%
stages
# Out:
# [StringIndexer_089ac286a3ab,
#  OneHotEncoder_3660f8b2d3bd,
#  StringIndexer_7db43d6b9529,
#  OneHotEncoder_27108c2f204e,
#  StringIndexer_7a527e6bfb6f,
#  OneHotEncoder_a57b919d1179,
#  StringIndexer_5fe62a350fd9,
#  OneHotEncoder_929ef3ab3a4f,
#  StringIndexer_32a4d77b79fd,
#  OneHotEncoder_63e623535ddb,
#  StringIndexer_5394ec7ba2ed,
#  OneHotEncoder_b93c1c6a58c2,
#  StringIndexer_2f0a6cacd31d,
#  VectorAssembler_74befe2719f0]

# %%
from pyspark.ml import Pipeline

# %%
df_cols=train_df2.select("city","city_development_index","gender","relevent_experience","enrolled_university","education_level","major_discipline","experience","last_new_job","training_hours","target")
cols=df_cols.columns
df_cols.printSchema()
# Out:
# root
#  |-- city: string (nullable = true)
#  |-- city_development_index: double (nullable = true)
#  |-- gender: string (nullable = false)
#  |-- relevent_experience: string (nullable = true)
#  |-- enrolled_university: string (nullable = false)
#  |-- education_level: string (nullable = true)
#  |-- major_discipline: string (nullable = true)
#  |-- experience: integer (nullable = true)
#  |-- last_new_job: integer (nullable = true)
#  |-- training_hours: integer (nullable = true)
#  |-- target: double (nullable = true)

# %%
from pyspark.ml.classification import DecisionTreeClassifier

# %%
pipeline = Pipeline(stages = stages)
pipelineModel = pipeline.fit(df_cols)
df = pipelineModel.transform(df_cols)
selectedCols = ['label', 'features'] + cols
df = df.select(selectedCols)
df.printSchema()
# Out:
# root
#  |-- label: double (nullable = false)
#  |-- features: vector (nullable = true)
#  |-- city: string (nullable = true)
#  |-- city_development_index: double (nullable = true)
#  |-- gender: string (nullable = false)
#  |-- relevent_experience: string (nullable = true)
#  |-- enrolled_university: string (nullable = false)
#  |-- education_level: string (nullable = true)
#  |-- major_discipline: string (nullable = true)
#  |-- experience: integer (nullable = true)
#  |-- last_new_job: integer (nullable = true)
#  |-- training_hours: integer (nullable = true)
#  |-- target: double (nullable = true)

# %%
(trainingData, testData) = df.randomSplit([0.7, 0.3])
print("Training Dataset Count: " + str(trainingData.count()))
print("Test Dataset Count: " + str(testData.count()))
# Out:
# Training Dataset Count: 11508
# Test Dataset Count: 4837

# %%
from pyspark.ml.classification import DecisionTreeClassifier
dt = DecisionTreeClassifier(featuresCol = 'features', labelCol = 'label')
dtModel = dt.fit(trainingData)
predictions = dtModel.transform(testData)

# %%
tp = predictions[(predictions.label == 1) & (predictions.prediction == 1)].count()
tn = predictions[(predictions.label == 0) & (predictions.prediction == 0)].count()
fp = predictions[(predictions.label == 0) & (predictions.prediction == 1)].count()
fn = predictions[(predictions.label == 1) & (predictions.prediction == 0)].count()
print("True Positive: ",tp,"\nTrue Negative: ",tn,"\nFalse Positive: ",fp,"\nFalse Negative: ",fn)
print("Recall: ",tp/(tp+fn))
print("Precision: ", tp/(tp+fp))
# Out:
# True Positive:  538
# True Negative:  3182
# False Positive:  361
# False Negative:  756
# Recall:  0.41576506955177744
# Precision:  0.5984427141268076

# %%
predictions.groupby("prediction")\
        .count()\
        .show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |       0.0| 3938|
# |       1.0|  899|
# +----------+-----+

# %%
from pyspark.ml.classification import LogisticRegression
lr = LogisticRegression(featuresCol = 'features', labelCol = 'label',maxIter=1000)
lrModel = lr.fit(train)

# %%
predict = lrModel.transform(test)

# %%
tp = predict[(predict.label == 1) & (predict.prediction == 1)].count()
tn = predict[(predict.label == 0) & (predict.prediction == 0)].count()
fp = predict[(predict.label == 0) & (predict.prediction == 1)].count()
fn = predict[(predict.label == 1) & (predict.prediction == 0)].count()
print("True Positive: ",tp,"\nTrue Negative: ",tn,"\nFalse Positive: ",fp,"\nFalse Negative: ",fn)
print("Recall: ",tp/(tp+fn))
print("Precision: ", tp/(tp+fp))
# Out:
# True Positive:  326
# True Negative:  2173
# False Positive:  250
# False Negative:  488
# Recall:  0.4004914004914005
# Precision:  0.5659722222222222

# %%
predict.groupby("prediction")\
        .count()\
        .show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |       0.0| 2661|
# |       1.0|  576|
# +----------+-----+

# %%
from pyspark.ml.classification import RandomForestClassifier
RFC = RandomForestClassifier(featuresCol = 'features', labelCol = 'label', numTrees=7,maxDepth=7,seed=52)
RFCmodel = dt.fit(train)
pred = RFCmodel.transform(test)

# %%
tp = pred[(pred.label == 1) & (pred.prediction == 1)].count()
tn = pred[(pred.label == 0) & (pred.prediction == 0)].count()
fp = pred[(pred.label == 0) & (pred.prediction == 1)].count()
fn = pred[(pred.label == 1) & (pred.prediction == 0)].count()
print("True Positive: ",tp,"\nTrue Negative: ",tn,"\nFalse Positive: ",fp,"\nFalse Negative: ",fn)
print("Recall: ",tp/(tp+fn))
print("Precision: ", tp/(tp+fp))
# Out:
# True Positive:  342
# True Negative:  2149
# False Positive:  274
# False Negative:  472
# Recall:  0.4201474201474201
# Precision:  0.5551948051948052

# %%
trainingData.groupby("target")\
        .count()\
        .show()
# Out:
# +------+-----+
# |target|count|
# +------+-----+
# |   0.0| 8574|
# |   1.0| 2934|
# +------+-----+

# %%
from pyspark.ml.classification import GBTClassifier
gbt = GBTClassifier(featuresCol = 'features', labelCol = 'label', maxIter=100,maxDepth=6)
model = gbt.fit(train)
pred1 = model.transform(test)

# %%
pred1.groupby("prediction")\
        .count()\
        .show()
# Out:
# +----------+-----+
# |prediction|count|
# +----------+-----+
# |       0.0| 2579|
# |       1.0|  658|
# +----------+-----+

# %%
tp = pred1[(pred1.label == 1) & (pred1.prediction == 1)].count()
tn = pred1[(pred1.label == 0) & (pred1.prediction == 0)].count()
fp = pred1[(pred1.label == 0) & (pred1.prediction == 1)].count()
fn = pred1[(pred1.label == 1) & (pred1.prediction == 0)].count()
print("True Positive: ",tp,"\nTrue Negative: ",tn,"\nFalse Positive: ",fp,"\nFalse Negative: ",fn)
print("Recall: ",tp/(tp+fn))
print("Precision: ", tp/(tp+fp))
# Out:
# True Positive:  368
# True Negative:  2133
# False Positive:  290
# False Negative:  446
# Recall:  0.4520884520884521
# Precision:  0.5592705167173252

# %%
zeros = df.filter(df["Target"]==0)

# %%
ones = df.filter(df["Target"]==1)
# split datasets into training and testing
train0, test0 = zeros.randomSplit([0.8,0.2], seed=1234)
train1, test1 = ones.randomSplit([0.8,0.2], seed=1234)
# stack datasets back together
train = train0.union(train1)
test = test0.union(test1)

# %%
zeros=zeros.take(2934)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-5d6ab4beda32> in <module>()
# ----> 1 zeros=zeros.take(2934).toDf.collect()
#
# AttributeError: 'list' object has no attribute 'toDf'

# %%
zeros.toDF("label","features","city","city_development_index","gender","relevent_experience","enrolled_university","education_level","major_discipline","experience","last_new_job","training_hours","target").collect()

# %%
zeros
# Out:
# DataFrame[label: double, features: vector, city: string, city_development_index: double, gender: string, relevent_experience: string, enrolled_university: string, education_level: string, major_discipline: string, experience: int, last_new_job: int, training_hours: int, target: double]
